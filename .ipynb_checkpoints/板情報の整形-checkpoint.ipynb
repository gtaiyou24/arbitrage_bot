# %%
import numpy as np
import pandas as pd

from exchangers.quoine_exchanger import QuoineExchanger
from exchangers.bitflyer_lightning_exchanger import BitFlyerLightningExchanger

# %%
board = BitFlyerLightningExchanger().get_board()

# %%
list(pd.DataFrame(board['asks']).rename(columns={'size': 'quantity'}).T.to_dict().values())
# Out:
# [{'price': 939650.0, 'quantity': 0.03},
#  {'price': 939701.0, 'quantity': 0.16183495},
#  {'price': 939706.0, 'quantity': 0.0104},
#  {'price': 939735.0, 'quantity': 0.81446053},
#  {'price': 939798.0, 'quantity': 0.03},
#  {'price': 939844.0, 'quantity': 0.001},
#  {'price': 940000.0, 'quantity': 0.001},
#  {'price': 940088.0, 'quantity': 0.796},
#  {'price': 940264.0, 'quantity': 0.02},
#  {'price': 940387.0, 'quantity': 1.10000026},
#  {'price': 940388.0, 'quantity': 0.119988},
#  {'price': 940594.0, 'quantity': 0.05},
#  {'price': 940641.0, 'quantity': 0.80000013},
#  {'price': 940642.0, 'quantity': 20.0},
#  {'price': 940707.0, 'quantity': 4.8226},
#  {'price': 940901.0, 'quantity': 0.1},
#  {'price': 941000.0, 'quantity': 0.00847},
#  {'price': 941025.0, 'quantity': 0.01},
#  {'price': 941090.0, 'quantity': 1.0},
#  {'price': 941425.0, 'quantity': 1.0},
#  {'price': 941540.0, 'quantity': 1.6},
#  {'price': 941624.0, 'quantity': 0.05},
#  {'price': 941662.0, 'quantity': 0.94},
# ...

# %%
pd.DataFrame(board['sell_price_levels'], columns=['price', 'quantity']).T.to_dict().values()
# Out:
# dict_values([{'price': '940708.02000000', 'quantity': '0.09620000'}, {'price': '940709.00000000', 'quantity': '0.50000013'}, {'price': '940807.00000000', 'quantity': '0.32850000'}, {'price': '940812.99000000', 'quantity': '0.43050000'}, {'price': '940880.46000000', 'quantity': '1.50635000'}, {'price': '940880.57000000', 'quantity': '0.10485000'}, {'price': '941088.00000000', 'quantity': '0.02850000'}, {'price': '941093.00000000', 'quantity': '0.60000013'}, {'price': '941093.03000000', 'quantity': '0.20000000'}, {'price': '941171.99000000', 'quantity': '0.40000000'}, {'price': '941172.00000000', 'quantity': '0.05000000'}, {'price': '941176.71000000', 'quantity': '0.06000000'}, {'price': '941246.02000000', 'quantity': '0.06000000'}, {'price': '941271.79000000', 'quantity': '0.06000000'}, {'price': '941301.00000000', 'quantity': '0.06000000'}, {'price': '941346.02000000', 'quantity': '0.06000000'}, {'price': '941600.96000000', 'quantity': '0.40000000'}, {'price': '941600.97000000', 'qua
# ...
